# %%
import matplotlib.pyplot as mp
import numpy as np
import lightcurves
import sys
#from ipywidgets import widgets
# %matplotlib inline

# %%
target = 'NGC3201'
folder = '/Users/jrneeley/CRRP/'+target+'/'
optical_folder = '/Users/jrneeley/CRRP/OpticalCatalogs/'

dtype1 = np.dtype([('id', 'S4'), ('cc_period', float), ('new_period', float)])
data = np.loadtxt(folder+target+'-variables.txt', dtype=dtype1, usecols=(0,1,2))

# %%
for ind, star in enumerate(data['id']):
    try:
        if np.isnan(data['new_period'][ind]):
      #      lightcurves.phase_lcv(folder+'lcvs/mir/'+star+'.lcv', data['cc_period'][ind], 0, bin=1, save=1)
            lightcurves.phase_lcv_all_bands(target, star+'.lcv',data['cc_period'][ind], 0, bin_mir=1, folder=folder)
        else:
      #      lightcurves.phase_lcv(folder+'lcvs/mir/'+star+'.lcv', data['new_period'][ind], 0, bin=1, save=1)
            lightcurves.phase_lcv_all_bands(target, star+'.lcv',data['new_period'][ind], 0, bin_mir=1, folder=folder)
    except:
        print star, ' not found.'
        continue

# %%
lightcurves.phase_lcv_all_bands(target, 'V81.lcv', 0.5197559, 0, bin_mir=1, folder=folder)

# %%
f = open(folder+'avg_mags.txt', 'a')
#stars = ['V76', 'V77', 'V78', 'V80', 'V81', 'V83', 'V84', 'V90', 'V92', 'V98', 'V100']
#for ind, star in enumerate(stars):
star = data['id'][28]
#for ind, star in enumerate(stars):
#sigmas = np.array([0.15, 0.05, 0.05, 0.2, 0.05, 0, 0, 0, 0.1, 0])
#sigmas = np.array([0.05, 0.05, 0.1, 0.2, 0.15, 0.05])
    
r1, r2, r3, r4 = lightcurves.gloess(folder+'lcvs/'+star+'.phased', plot_save=1, clean=1)
datasave = np.array(zip(np.repeat(star, len(r1)), r1, np.repeat(data['new_period'][ind], len(r1)), r2, r3, r4), dtype=[('c1', 'S3'), ('c2', 'S2'), ('c3', float), ('c4', float), ('c5', float), ('c6', float)])
np.savetxt(f, datasave, fmt='%3s %2s %10.8f %6.3f %4.2f %4.2f')
    
f.close()
# Out:
# /Users/jrneeley/CRRP/NGC3201/lcvs/V29.phased
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.08
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.1
# Are you happy with this fit? [y/n]: y
# B 15.424785048 0.779819707718
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.12
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.14
# Are you happy with this fit? [y/n]: y
# I 13.9776450182 0.557356246574
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.15
# Are you happy with this fit? [y/n]: y
# I1 12.9375062552 0.143498318088
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.15
# Are you happy with this fit? [y/n]: y
# I2 13.0828105477 0.183093082204
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.08
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.12
# Are you happy with this fit? [y/n]: n
# Enter new smoothing parameter: 0.1
# Are you happy with this fit? [y/n]: y
# V 14.825282396 0.610526537674

# %%
f.close()
