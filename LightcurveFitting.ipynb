# %%
import matplotlib.pyplot as mp
import numpy as np
import lightcurves
import sys
#from ipywidgets import widgets
# %matplotlib inline

# %%
target = 'NGC3201'
folder = '/Users/jrneeley/CRRP/'+target+'/'
optical_folder = '/Users/jrneeley/CRRP/OpticalCatalogs/'

# %%
dtype1 = np.dtype([('id', 'S4'), ('cc_period', float), ('new_period', float)])
data = np.loadtxt(folder+target+'-variables.txt', dtype=dtype1, usecols=(0,1,2))
#for ind, star in enumerate(data['id']):
 #   try:
  #      if np.isnan(data['new_period'][ind]):
   #       #  lightcurves.phase_lcv(folder+'lcvs/mir/'+star+'.lcv', data['cc_period'][ind], 0, save=1)
    #        lightcurves.phase_lcv_all_bands(target, star+'.lcv',data['cc_period'][ind], 0, bin_mir=0, folder=folder)
     #   else:
          #  lightcurves.phase_lcv(folder+'lcvs/mir/'+star+'.lcv', data['new_period'][ind], 0, save=1)
      #      lightcurves.phase_lcv_all_bands(target, star+'.lcv',data['new_period'][ind], 0, bin_mir=0, folder=folder)
  #  except:
   #     print star, ' not found.'
    #    continue

# %%
f = open(folder+'avg_mags.txt', 'a')
stars = ['V76', 'V77', 'V78', 'V80', 'V81', 'V83', 'V84', 'V90', 'V92', 'V98', 'V100']
#for ind, star in enumerate(stars):
for ind, star in enumerate(data['id']):
#sigmas = np.array([0.15, 0.05, 0.05, 0.2, 0.05, 0, 0, 0, 0.1, 0])
#sigmas = np.array([0.05, 0.05, 0.1, 0.2, 0.15, 0.05])
    
    r1, r2, r3, r4 = lightcurves.gloess(folder+'lcvs/'+star+'.phased', plot_save=1)
    datasave = np.array(zip(np.repeat(star, len(r1)), r1, np.repeat(data['new_period'][ind], len(r1)), r2, r3, r4), dtype=[('c1', 'S3'), ('c2', 'S2'), ('c3', float), ('c4', float), ('c5', float), ('c6', float)])
    np.savetxt(f, datasave, fmt='%3s %2s %10.8f %6.3f %4.2f %4.2f')
# Out:
# close failed in file object destructor:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# IOError: [Errno 13] Permission denied
# /Users/jrneeley/CRRP/NGC3201/lcvs/V76.phased
# 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-9192be454a6c> in <module>()
#       5 #sigmas = np.array([0.05, 0.05, 0.1, 0.2, 0.15, 0.05])
#       6
# ----> 7     r1, r2, r3, r4 = lightcurves.gloess(folder+'lcvs/'+star+'.phased', plot_save=1)
#       8     datasave = np.array(zip(np.repeat(star, len(r1)), r1, r2, r3, r4), dtype=[('c1', 'S3'), ('c2', 'S2'), ('c3', float), ('c4', float), ('c5', float)])
#       9     np.savetxt(f, datasave, fmt='%3s %2s %6.3f %4.2f %4.2f')
#
# /Users/jrneeley/CRRP/python/CRRP-photometry/lightcurves.pyc in gloess(phased_lcv_file, clean, smoothing_params, plot_save, folder)
#     877                 happy = 'y'
#     878                 continue
# --> 879             check = raw_input('Are you happy with this fit? [y/n]: ')
#     880             if check == 'n':
#     881                 sigma = input('Enter new smoothing parameter: ')
#
# /Users/jrneeley/anaconda2/envs/astroconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /Users/jrneeley/anaconda2/envs/astroconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
