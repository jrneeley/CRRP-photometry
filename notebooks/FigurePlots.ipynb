# %%
import numpy as np
import matplotlib.pyplot as mp
# %matplotlib inline 
import sys
sys.path.insert(0, '/Volumes/Annie/CRRP/python/CRRP-photometry/')
import analysis_routines

red_law = [1.579, 1.348, 1.016, 0.845, 0.590, 0.289, 0.181, 0.118, 0.066, 0.051] 
Rv = 3.1

N3201_dir = '/Volumes/Annie/CRRP/NGC3201/'
N5904_dir = '/Volumes/Annie/CRRP/NGC5904/'
N6402_dir = '/Volumes/Annie/CRRP/NGC6402/'
N7078_dir = '/Volumes/Annie/CRRP/NGC7078/'

# %%
# select only stars used in PL 

N3201_3p6_use = np.array(['V1', 'V10', 'V100', 'V12', 'V13', 'V14', 'V17', 'V18', 'V19', 'V2', 'V20', 'V21',
 'V22', 'V23', 'V25', 'V26', 'V28', 'V29', 'V3', 'V31', 'V32', 'V34', 'V35', 'V37',
 'V4', 'V40', 'V41', 'V42', 'V44', 'V47', 'V48', 'V49', 'V5', 'V51', 'V56', 'V57',
 'V58', 'V6', 'V7', 'V71', 'V77', 'V78', 'V8', 'V80', 'V83', 'V98'])
N3201_4p5_use = ['V1', 'V10', 'V100', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V19', 'V2', 'V20',
 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V29', 'V3', 'V31', 'V32', 'V35', 'V37',
 'V39', 'V4', 'V40', 'V42', 'V43', 'V44', 'V47', 'V48', 'V49', 'V5', 'V51', 'V57',
 'V59', 'V6', 'V67', 'V71', 'V73', 'V76', 'V78', 'V8', 'V80', 'V83', 'V9', 'V98']
N5904_3p6_use = ['V1', 'V11', 'V114', 'V12', 'V130', 'V14', 'V16', 'V161', 'V17', 'V26', 'V27', 'V30',
 'V33', 'V34', 'V36', 'V38', 'V4', 'V40', 'V41', 'V45', 'V5', 'V52', 'V54', 'V55',
 'V56', 'V59', 'V64', 'V65', 'V7', 'V78', 'V80', 'V81', 'V82', 'V83', 'V85', 'V87',
 'V89', 'V90', 'V91', 'V95', 'V96']
N5904_4p5_use = ['V1', 'V11', 'V114', 'V115', 'V12', 'V129', 'V130', 'V139', 'V14', 'V16', 'V161',
 'V17', 'V26', 'V27', 'V30', 'V33', 'V34', 'V36', 'V38', 'V4', 'V40', 'V41', 'V44',
 'V45', 'V47', 'V5', 'V54', 'V55', 'V56', 'V57', 'V59', 'V64', 'V65', 'V7', 'V80',
 'V81', 'V86', 'V87', 'V89', 'V90', 'V91', 'V96', 'V97']
N7078_3p6_use = ['NV6', 'V10', 'V102=NV10', 'V11', 'V12', 'V13', 'V16', 'V19', 'V2', 'V20', 'V21',
 'V22', 'V23', 'V24', 'V25', 'V3', 'V32', 'V35', 'V36', 'V37', 'V38', 'V4', 'V40',
 'V42', 'V44', 'V45', 'V46=V112', 'V48', 'V5', 'V50', 'V52', 'V56', 'V6', 'V60', 'V63',
 'V65', 'V66', 'V74', 'V8', 'V9', 'V97', 'V99']
N7078_4p5_use = ['NV6', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V18', 'V19', 'V2', 'V20',
 'V21', 'V23', 'V24', 'V25', 'V3', 'V35', 'V36', 'V37', 'V38', 'V40', 'V41', 'V42',
 'V44', 'V45', 'V46=V112', 'V48', 'V49', 'V5', 'V50', 'V52', 'V55', 'V56', 'V6', 'V60',
 'V65', 'V66', 'V7', 'V74', 'V8', 'V9', 'V97', 'V99']
N6402_3p6_use = ['V10', 'V110', 'V111', 'V118', 'V13', 'V130', 'V133', 'V14', 'V140', 'V15', 'V150',
               'V16', 'V160', 'V18', 'V19', 'V20', 'V22', 'V23', 'V24', 'V3', 'V32', 'V33', 'V34',
 'V39', 'V4', 'V42', 'V43', 'V44', 'V46', 'V48', 'V49', 'V5', 'V57', 'V58', 'V59',
 'V75', 'V77', 'V78', 'V8', 'V9', 'V98']
N6402_4p5_use = ['V10', 'V106', 'V110', 'V118', 'V13', 'V130', 'V14', 'V140', 'V141', 'V143', 'V15',
 'V150', 'V19', 'V22', 'V24', 'V25', 'V3', 'V31', 'V32', 'V33', 'V34', 'V42', 'V43',
 'V44', 'V47', 'V59', 'V60', 'V70', 'V75', 'V77', 'V8', 'V80', 'V88', 'V9']

# %% [markdown]
# # Color-Magnitude Diagrams

# %%
# NGC 3201
cluster_ra = '10:17:36.82'
cluster_dec = '-46:24:44.9'
ebv = 0.24
feh = -1.59
mu = 13.40
target_dir = '/Volumes/Annie/CRRP/NGC3201/'

# read in catalog data
N3201_data = analysis_routines.read_merged_catalog(target_dir)

# apply extinction
N3201_data['V'] = N3201_data['V'] - Rv*ebv*red_law[2]
N3201_data['B'] = N3201_data['B'] - Rv*ebv*red_law[1]
N3201_data['3.6'] = N3201_data['3.6'] - Rv*ebv*red_law[8]
N3201_data['4.5'] = N3201_data['4.5'] - Rv*ebv*red_law[9]
dist = N3201_data['rad_dist']

outer_thresh = 300
inner_thresh = 150

select  = (dist > inner_thresh) & (dist < outer_thresh)
N3201_opt_color = N3201_data['B'][select] - N3201_data['V'][select]
N3201_opt_mag = N3201_data['V'][select]

N3201_mir_color = N3201_data['V'][select] - N3201_data['3.6'][select]
N3201_mir_mag = N3201_data['3.6'][select]

# %%
# NGC 5904
cluster_ra = '15:18:33.22'
cluster_dec = '02:04:51.7'
ebv = 0.03
feh = -1.29
mu = 14.35
target_dir = '/Volumes/Annie/CRRP/NGC5904/'

# read in catalog data
N5904_data = analysis_routines.read_merged_catalog(target_dir)

# apply extinction
N5904_data['V'] = N5904_data['V'] - Rv*ebv*red_law[2]
N5904_data['B'] = N5904_data['B'] - Rv*ebv*red_law[1]
N5904_data['3.6'] = N5904_data['3.6'] - Rv*ebv*red_law[8]
N5904_data['4.5'] = N5904_data['4.5'] - Rv*ebv*red_law[9]
dist = N5904_data['rad_dist']

outer_thresh = 300
inner_thresh = 150

select  = (dist > inner_thresh) & (dist < outer_thresh)
N5904_opt_color = N5904_data['B'][select] - N5904_data['V'][select]
N5904_opt_mag = N5904_data['V'][select]

N5904_mir_color = N5904_data['V'][select] - N5904_data['3.6'][select]
N5904_mir_mag = N5904_data['3.6'][select]

# %%
# NGC 6402
cluster_ra = '17:37:36.10'
cluster_dec = '-03:14:45.3'
ebv = 0.60
feh = -1.28
mu = 15.0
target_dir = '/Volumes/Annie/CRRP/NGC6402/'

# read in catalog data
N6402_data = analysis_routines.read_merged_catalog(target_dir)

# apply extinction
N6402_data['V'] = N6402_data['V'] - Rv*ebv*red_law[2]
N6402_data['B'] = N6402_data['B'] - Rv*ebv*red_law[1]
N6402_data['3.6'] = N6402_data['3.6'] - Rv*ebv*red_law[8]
N6402_data['4.5'] = N6402_data['4.5'] - Rv*ebv*red_law[9]
dist = N6402_data['rad_dist']

outer_thresh = 300
inner_thresh = 150

select  = (dist > inner_thresh) & (dist < outer_thresh)
N6402_opt_color = N6402_data['B'][select] - N6402_data['V'][select]
N6402_opt_mag = N6402_data['V'][select]

N6402_mir_color = N6402_data['V'][select] - N6402_data['3.6'][select]
N6402_mir_mag = N6402_data['3.6'][select]

# %%
# NGC 7078
cluster_ra = '21:29:58.33'
cluster_dec = '12:10:01.2'
ebv = 0.10
feh = -2.37
mu = 15.13
target_dir = '/Volumes/Annie/CRRP/NGC7078/'

# read in catalog data
N7078_data = analysis_routines.read_merged_catalog(target_dir)

# apply extinction
N7078_data['V'] = N7078_data['V'] - Rv*ebv*red_law[2]
N7078_data['B'] = N7078_data['B'] - Rv*ebv*red_law[1]
N7078_data['3.6'] = N7078_data['3.6'] - Rv*ebv*red_law[8]
N7078_data['4.5'] = N7078_data['4.5'] - Rv*ebv*red_law[9]
dist = N7078_data['rad_dist']

outer_thresh = 300
inner_thresh = 150

select  = (dist > inner_thresh) & (dist < outer_thresh)
N7078_opt_color = N7078_data['B'][select] - N7078_data['V'][select]
N7078_opt_mag = N7078_data['V'][select]

N7078_mir_color = N7078_data['V'][select] - N7078_data['3.6'][select]
N7078_mir_mag = N7078_data['3.6'][select]

# %%
f, ((ax1, ax2), (ax3, ax4)) = mp.subplots(2, 2, sharex='col', sharey='row', figsize=(10,8))

ax1.scatter(N3201_opt_color, N3201_opt_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax2.scatter(N5904_opt_color, N5904_opt_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax3.scatter(N6402_opt_color, N6402_opt_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax4.scatter(N7078_opt_color, N7078_opt_mag, s=1, edgecolor=None, color='xkcd:blue grey')

ax1.set_ylim((25,10))
ax2.set_ylim((25,10))
ax3.set_ylim((25,10))
ax4.set_ylim((25,10))
ax1.set_xlim((-0.5,2))
ax2.set_xlim((-0.5,2))
ax3.set_xlim((-0.5,2))
ax4.set_xlim((-0.5,2))

ax3.set_xlabel('B - V')
ax4.set_xlabel('B - V')
ax1.set_ylabel('V')
ax3.set_ylabel('V')

ax1.annotate('NGC 3201', xy=(-.4, 11))
ax2.annotate('NGC 5904', xy=(-.4, 11))
ax3.annotate('NGC 6402', xy=(-.4, 11))
ax4.annotate('NGC 7078', xy=(-.4, 11))

mp.savefig('optical-cmds.eps', format='eps')

# %%
f, ((ax1, ax2), (ax3, ax4)) = mp.subplots(2, 2, sharex='col', sharey='row', figsize=(10,8))

ax1.scatter(N3201_mir_color, N3201_mir_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax2.scatter(N5904_mir_color, N5904_mir_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax3.scatter(N6402_mir_color, N6402_mir_mag, s=1, edgecolor=None, color='xkcd:blue grey')
ax4.scatter(N7078_mir_color, N7078_mir_mag, s=1, edgecolor=None, color='xkcd:blue grey')

ax1.set_ylim((22,7))
ax2.set_ylim((22,7))
ax3.set_ylim((22,7))
ax4.set_ylim((22,7))
ax1.set_xlim((-1,5))
ax2.set_xlim((-1,5))
ax3.set_xlim((-1,5))
ax4.set_xlim((-1,5))

ax3.set_xlabel('V - [3.6]')
ax4.set_xlabel('V - [3.6]')
ax1.set_ylabel('[3.6]')
ax3.set_ylabel('[3.6]')

ax1.annotate('NGC 3201', xy=(-.8, 9))
ax2.annotate('NGC 5904', xy=(-.8, 9))
ax3.annotate('NGC 6402', xy=(-.8, 9))
ax4.annotate('NGC 7078', xy=(-.8, 9))

mp.savefig('mir-cmds.eps', format='eps')

# %% [markdown]
# # Bailey diagrams

# %%
dtype = np.dtype([('name', 'S10'), ('period', float), ('mode', 'S6'), ('dist', float), ('U', float), ('Uer', float), 
                    ('Uamp', float), ('B', float), ('Ber', float), ('Bamp', float), ('V', float),
                    ('Ver', float), ('Vamp', float), ('R', float), ('Rer', float), ('Ramp', float),
                    ('I', float), ('Ier', float), ('Iamp', float), ('J', float), ('Jer', float),
                    ('Jamp', float), ('H', float), ('Her', float), ('Hamp', float), ('K', float),
                    ('Ker', float), ('Kamp', float), ('3.6', float), ('3.6er', float), ('3.6amp', float),
                    ('4.5', float), ('4.5er', float), ('4.5amp', float)])

# NGC 3201
N3201_data = np.loadtxt(N3201_dir+'RRL-avg-mags.txt', dtype=dtype)
N3201_rrc = N3201_data['mode'] == 'RR1'
N3201_rrab = N3201_data['mode'] == 'RR0'
N3201_rrd = N3201_data['mode'] == 'RR01'
N3201_3p6 = (N3201_data['3.6'] < 90) & (np.in1d(N3201_data['name'], N3201_3p6_use) == True)
N3201_4p5 = (N3201_data['4.5'] < 90) & (np.in1d(N3201_data['name'], N3201_4p5_use) == True)

# NGC 5904
N5904_data = np.loadtxt(N5904_dir+'RRL-avg-mags.txt', dtype=dtype)
N5904_rrc = N5904_data['mode'] == 'RR1'
N5904_rrab = N5904_data['mode'] == 'RR0'
N5904_rrd = N5904_data['mode'] == 'RR01'
N5904_3p6 = (N5904_data['3.6'] < 90) & (np.in1d(N5904_data['name'], N5904_3p6_use) == True)
N5904_4p5 = (N5904_data['4.5'] < 90) & (np.in1d(N5904_data['name'], N5904_4p5_use) == True)

# NGC 6402
N6402_data = np.loadtxt(N6402_dir+'RRL-avg-mags.txt', dtype=dtype)
N6402_rrc = N6402_data['mode'] == 'RR1'
N6402_rrab = N6402_data['mode'] == 'RR0'
N6402_rrd = N6402_data['mode'] == 'RR01'
N6402_3p6 = (N6402_data['3.6'] < 90) & (np.in1d(N6402_data['name'], N6402_3p6_use) == True)
N6402_4p5 = (N6402_data['4.5'] < 90) & (np.in1d(N6402_data['name'], N6402_4p5_use) == True)

# NGC 7078
N7078_data = np.loadtxt(N7078_dir+'RRL-avg-mags.txt', dtype=dtype)
N7078_rrc = N7078_data['mode'] == 'RR1'
N7078_rrab = N7078_data['mode'] == 'RR0'
N7078_rrd = N7078_data['mode'] == 'RR01'
N7078_3p6 = (N7078_data['3.6'] < 90) & (np.in1d(N7078_data['name'], N7078_3p6_use) == True)
N7078_4p5 = (N7078_data['4.5'] < 90) & (np.in1d(N7078_data['name'], N7078_4p5_use) == True)

f, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = mp.subplots(4, 2, sharex='col', figsize=(8,12))

# bailey diagrams
ax1.scatter(N3201_data['period'][N3201_rrc], N3201_data['Vamp'][N3201_rrc], color='b')
ax1.scatter(N3201_data['period'][N3201_rrab], N3201_data['Vamp'][N3201_rrab], color='r')
ax1.scatter(N3201_data['period'][N3201_rrd], N3201_data['Vamp'][N3201_rrd], color='g')
ax3.scatter(N5904_data['period'][N5904_rrc], N5904_data['Vamp'][N5904_rrc], color='b')
ax3.scatter(N5904_data['period'][N5904_rrab], N5904_data['Vamp'][N5904_rrab], color='r')
ax3.scatter(N5904_data['period'][N5904_rrd], N5904_data['Vamp'][N5904_rrd], color='g')
ax5.scatter(N6402_data['period'][N6402_rrc], N6402_data['Vamp'][N6402_rrc], color='b')
ax5.scatter(N6402_data['period'][N6402_rrab], N6402_data['Vamp'][N6402_rrab], color='r')
ax5.scatter(N6402_data['period'][N6402_rrd], N6402_data['Vamp'][N6402_rrd], color='g')
ax7.scatter(N7078_data['period'][N7078_rrc], N7078_data['Vamp'][N7078_rrc], color='b')
ax7.scatter(N7078_data['period'][N7078_rrab], N7078_data['Vamp'][N7078_rrab], color='r')
ax7.scatter(N7078_data['period'][N7078_rrd], N7078_data['Vamp'][N7078_rrd], color='g')

# period distribution
ax2.hist(N3201_data['period'], bins='auto', fill=False, histtype='step') 
ax4.hist(N5904_data['period'], bins='auto', fill=False, histtype='step') 
ax6.hist(N6402_data['period'], bins='auto', fill=False, histtype='step') 
ax8.hist(N7078_data['period'], bins='auto', fill=False, histtype='step') 

ax7.set_xlabel('Period [days]')
ax8.set_xlabel('Period [days]')
ax1.set_ylabel('V amp')
ax3.set_ylabel('V amp')
ax5.set_ylabel('V amp')
ax7.set_ylabel('V amp')

ax1.annotate('NGC 3201', xy=(0.2, 1.2))
ax3.annotate('NGC 5904', xy=(0.2, 1.25))
ax5.annotate('NGC 6402', xy=(0.2, 1.25))
ax7.annotate('NGC 7078', xy=(0.2, 2.2))

N3201_pab = np.nanmean(N3201_data['period'][N3201_rrab])
N3201_pc = np.nanmean(N3201_data['period'][N3201_rrc])
Nc = float(len(N3201_data['period'][N3201_rrc]))
Ntot = float(len(N3201_data['period']))
N3201_ratio = Nc/Ntot
N5904_pab = np.nanmean(N5904_data['period'][N5904_rrab])
N5904_pc = np.nanmean(N5904_data['period'][N5904_rrc])
Nc = float(len(N5904_data['period'][N5904_rrc]))
Ntot = float(len(N5904_data['period']))
N5904_ratio = Nc/Ntot
N6402_pab = np.nanmean(N6402_data['period'][N6402_rrab])
N6402_pc = np.nanmean(N6402_data['period'][N6402_rrc])
Nc = float(len(N6402_data['period'][N6402_rrc]))
Ntot = float(len(N6402_data['period']))
N6402_ratio = Nc/Ntot
N7078_pab = np.nanmean(N7078_data['period'][N7078_rrab])
N7078_pc = np.nanmean(N7078_data['period'][N7078_rrc])
Nc = float(len(N7078_data['period'][N7078_rrc]))
Ntot = float(len(N7078_data['period']))
N7078_ratio = Nc/Ntot

ax2.annotate('<Pab> {:.2f}'.format(N3201_pab), xy=(0.65,21))
ax2.annotate('<Pc> {:.2f}'.format(N3201_pc), xy=(0.65,19))
ax2.annotate('Nc/Ntot {:.2f}'.format(N3201_ratio), xy=(0.65,17))
ax4.annotate('<Pab> {:.2f}'.format(N5904_pab), xy=(0.65,20))
ax4.annotate('<Pc> {:.2f}'.format(N5904_pc), xy=(0.65,18))
ax4.annotate('Nc/Ntot {:.2f}'.format(N5904_ratio), xy=(0.65,16))
ax6.annotate('<Pab> {:.2f}'.format(N6402_pab), xy=(0.65,29))
ax6.annotate('<Pc> {:.2f}'.format(N6402_pc), xy=(0.65,26))
ax6.annotate('Nc/Ntot {:.2f}'.format(N6402_ratio), xy=(0.65,23))
ax8.annotate('<Pab> {:.2f}'.format(N7078_pab), xy=(0.65,40))
ax8.annotate('<Pc> {:.2f}'.format(N7078_pc), xy=(0.65,36))
ax8.annotate('Nc/Ntot {:.2f}'.format(N7078_ratio), xy=(0.65,32))

mp.savefig('bailey.eps', format='eps')

# %% [markdown]
# # Amplitude Ratio

# %%
f, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = mp.subplots(4, 2, sharex='col', sharey='col', figsize=(8,12))

N3201_abav = (N3201_data['Bamp'] < 9) & (N3201_data['Vamp'] < 9)
N3201_as1av = (N3201_data['3.6amp'] < 9) & (N3201_data['Vamp'] < 9)
N3201_r1 = N3201_data['Bamp'][N3201_abav]/N3201_data['Vamp'][N3201_abav]
N3201_r2 = N3201_data['3.6amp'][N3201_as1av]/N3201_data['Vamp'][N3201_as1av]
N5904_abav = (N5904_data['Bamp'] < 9) & (N5904_data['Vamp'] < 9)
N5904_as1av = (N5904_data['3.6amp'] < 9) & (N5904_data['Vamp'] < 9)
N5904_r1 = N5904_data['Bamp'][N5904_abav]/N5904_data['Vamp'][N5904_abav]
N5904_r2 = N5904_data['3.6amp'][N5904_as1av]/N5904_data['Vamp'][N5904_as1av]
N6402_abav = (N6402_data['Bamp'] < 9) & (N6402_data['Vamp'] < 9)
N6402_as1av = (N6402_data['3.6amp'] < 9) & (N6402_data['Vamp'] < 9)
N6402_r1 = N6402_data['Bamp'][N6402_abav]/N6402_data['Vamp'][N6402_abav]
N6402_r2 = N6402_data['3.6amp'][N6402_as1av]/N6402_data['Vamp'][N6402_as1av]
N7078_abav = (N7078_data['Bamp'] < 9) & (N7078_data['Vamp'] < 9)
N7078_as1av = (N7078_data['3.6amp'] < 9) & (N7078_data['Vamp'] < 9)
N7078_r1 = N7078_data['Bamp'][N7078_abav]/N7078_data['Vamp'][N7078_abav]
N7078_r2 = N7078_data['3.6amp'][N7078_as1av]/N7078_data['Vamp'][N7078_as1av]

ax1.scatter(N3201_data['period'][N3201_abav], N3201_r1)
ax2.scatter(N3201_data['period'][N3201_as1av], N3201_r2)
ax3.scatter(N5904_data['period'][N5904_abav], N5904_r1)
ax4.scatter(N5904_data['period'][N5904_as1av], N5904_r2)
ax5.scatter(N6402_data['period'][N6402_abav], N6402_r1)
ax6.scatter(N6402_data['period'][N6402_as1av], N6402_r2)
ax7.scatter(N7078_data['period'][N7078_abav], N7078_r1)
ax8.scatter(N7078_data['period'][N7078_as1av], N7078_r2)

ax7.set_xlabel('Period [days]')
ax8.set_xlabel('Period [days]')
ax1.set_ylabel('B amp / V amp')
ax2.set_ylabel('[3.6] amp / V amp')
ax3.set_ylabel('B amp / V amp')
ax4.set_ylabel('[3.6] amp / V amp')
ax5.set_ylabel('B amp / V amp')
ax6.set_ylabel('[3.6] amp / V amp')
ax7.set_ylabel('B amp / V amp')
ax8.set_ylabel('[3.6] amp / V amp')

ax1.annotate('NGC 3201', xy=(0.2, 2.4))
ax3.annotate('NGC 5904', xy=(0.2, 2.4))
ax5.annotate('NGC 6402', xy=(0.2, 2.4))
ax7.annotate('NGC 7078', xy=(0.2, 2.4))

mp.savefig('amp-ratio.eps', format='eps')
